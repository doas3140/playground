# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from tqdm import tqdm_notebook
from fastai import *
from fastai.vision import *
from fastai.metrics import error_rate

from preparation import get_logos, get_nr2classname_dict
nr2c = get_nr2classname_dict()
c2nr = {a:int(aa) for aa,a in nr2c.items()}
logos = get_logos()

# %%
classes = [c for i,c in nr2c.items() if i != 0]

# %%
logos[0].ann[0].bb # x1 y1 x2 y2, where (y1,x1) is bottom left corner
# Out:
# [411, 499, 464, 538]

# %%
def create_annotations(logos):
    name2ann = {}
    for lg in logos:
        bb = [[a.bb[1],a.bb[0],a.bb[3],a.bb[2]] for a in lg.ann]
        cl = [a.c for a in lg.ann]
        name2ann[lg.path.name] = [bb,cl]
    return name2ann
    
name2a = create_annotations(logos)

# %%
def bb_pad_collate(samples:BatchSamples, pad_idx:int=0) -> Tuple[FloatTensor, Tuple[LongTensor, LongTensor]]:
    "Function that collect `samples` of labelled bboxes and adds padding with `pad_idx`."
    if isinstance(samples[0][1], int): return data_collate(samples)
    max_len = max([len(s[1].data[1]) for s in samples])
    bboxes = torch.zeros(len(samples), max_len, 4)
    labels = torch.zeros(len(samples), max_len).long() + pad_idx
    imgs = []
    for i,s in enumerate(samples):
        imgs.append(s[0].data[None])
        bbs, lbls = s[1].data
        if not (bbs.nelement() == 0):
            bboxes[i,-len(lbls):] = bbs
            labels[i,-len(lbls):] = tensor(lbls)
    return torch.cat(imgs,0), (bboxes,labels)

# %%
files = [x.path for x in logos if x.logo]
name2test = { x.path.name:x.test for x in logos }

tfms = get_transforms()

data = (ObjectItemList(files)
            .split_by_valid_func(lambda x: name2test[ x.name ])
            .label_from_func(lambda x: name2a[ x.name ])
            .transform(tfms, size=(224,224), tfm_y=True)
            .databunch(bs=16, collate_fn=bb_pad_collate)
            .normalize(imagenet_stats)
       )

# %%
data.show_batch(rows=2, ds_type=DatasetType.Train, figsize=(6,6))

# %%
valid_dl = data.dl(ds_type=DatasetType.Valid)
for i,(x,y) in enumerate(valid_dl):
    print(x.shape, len(y), y[0].shape, y[1].shape)
    if i > 3: break
# Out:
# torch.Size([16, 3, 224, 224]) 2 torch.Size([16, 8, 4]) torch.Size([16, 8])
# torch.Size([16, 3, 224, 224]) 2 torch.Size([16, 36, 4]) torch.Size([16, 36])
# torch.Size([16, 3, 224, 224]) 2 torch.Size([16, 4, 4]) torch.Size([16, 4])
# torch.Size([16, 3, 224, 224]) 2 torch.Size([16, 3, 4]) torch.Size([16, 3])
# torch.Size([16, 3, 224, 224]) 2 torch.Size([16, 8, 4]) torch.Size([16, 8])

# %% [markdown]
# # Model

# %%
model = models.resnet34(pretrained=True)
nn.Sequential(*list(model.modules())[1:]) # modifying first layers
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
